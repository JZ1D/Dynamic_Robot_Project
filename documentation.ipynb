# %% [markdown]
# ### Dokumentation zum Setup des Neura-Roboters

# %% [markdown]
# ## Start des Roboters
# - Hauptschalter anschalten
# - ggf. Touchpad anschalten, wenn es nicht automatisch hochfährt
#
# ## Modi

# %% [markdown]
# ## Modi des Roboterbedieners am Touchpad und den Berechtigungen
# 1. Admin
# 2. User
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Auslesen der gespeicherten globalen Positionen des Roboters über Python
# *check_teach_points.py*
# In dem Python-File werden alle gefundenen Punkte ausgegeben und zu jedem gefundenen Punkt
# - die Joints Position in rad
# - Kathesische Position in m
#
# Zusätzlich wird die *Aktuelle Roboter-Position* in Joints geprintet
